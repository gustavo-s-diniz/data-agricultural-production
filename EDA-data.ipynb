# %%
import pandas as pd

# %%
# Carregando o arquivo CSV
file_path = 'FAOSTAT_data_en_4-19-2024.csv'
data = pd.read_csv(file_path)

# Exibindo as primeiras linhas do DataFrame
data.tail(9)
# Out:
#     Domain Code                        Domain  Area Code    Area  \
# 177         QCL  Crops and livestock products         21  Brazil
# 178         QCL  Crops and livestock products         21  Brazil
# 179         QCL  Crops and livestock products         21  Brazil
# 180         QCL  Crops and livestock products         21  Brazil
# 181         QCL  Crops and livestock products         21  Brazil
# 182         QCL  Crops and livestock products         21  Brazil
# 183         QCL  Crops and livestock products         21  Brazil
# 184         QCL  Crops and livestock products         21  Brazil
# 185         QCL  Crops and livestock products         21  Brazil
#
#      Element Code         Element  Item Code              Item  Year Code  \
# 177          5312  Area harvested       1717  Cereals, primary       2020
# 178          5419           Yield       1717  Cereals, primary       2020
# 179          5510      Production       1717  Cereals, primary       2020
# ...
